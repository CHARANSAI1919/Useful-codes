# %%
import numpy as np
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
import matplotlib.pyplot as plt

# Sample text data
documents = [
    "This is the first document",
    "This document is the second document",
    "And this is the third one",
    "Is this the first document",
]

# Convert text data into numerical vectors using TF-IDF
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(documents)

# Perform hierarchical clustering
Z = linkage(tfidf_matrix.toarray(), 'ward')

# Get cluster labels
max_d = 1.0  # Adjust this threshold as needed
clusters = fcluster(Z, max_d, criterion='distance')

# Print cluster labels
print("Cluster labels:")
for i, label in enumerate(clusters):
    print(f"Document {i+1}: Cluster {label}")

# Plot dendrogram
plt.figure(figsize=(10, 5))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Index')
plt.ylabel('Distance')
dendrogram(Z, labels=documents, leaf_rotation=90)
plt.show()
# Out:
# Cluster labels:
# Document 1: Cluster 1
# Document 2: Cluster 1
# Document 3: Cluster 2
# Document 4: Cluster 1

# %%
# Perform hierarchical clustering
Z = linkage(tfidf_matrix.toarray(), 'single')

# Get cluster labels
max_d = 1.0  # Adjust this threshold as needed
clusters = fcluster(Z, max_d, criterion='distance')

# Print cluster labels
print("Cluster labels:")
for i, label in enumerate(clusters):
    print(f"Document {i+1}: Cluster {label}")

# Plot dendrogram
plt.figure(figsize=(10, 5))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Index')
plt.ylabel('Distance')
dendrogram(Z, labels=documents, leaf_rotation=90)
plt.show()
# Out:
# Cluster labels:
# Document 1: Cluster 1
# Document 2: Cluster 1
# Document 3: Cluster 2
# Document 4: Cluster 1

# %%
# Perform hierarchical clustering
Z = linkage(tfidf_matrix.toarray(), 'complete')

# Get cluster labels
max_d = 1.0  # Adjust this threshold as needed
clusters = fcluster(Z, max_d, criterion='distance')

# Print cluster labels
print("Cluster labels:")
for i, label in enumerate(clusters):
    print(f"Document {i+1}: Cluster {label}")

# Plot dendrogram
plt.figure(figsize=(10, 5))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Index')
plt.ylabel('Distance')
dendrogram(Z, labels=documents, leaf_rotation=90)
plt.show()
# Out:
# Cluster labels:
# Document 1: Cluster 1
# Document 2: Cluster 1
# Document 3: Cluster 2
# Document 4: Cluster 1

# %%
# Perform hierarchical clustering
Z = linkage(tfidf_matrix.toarray(), 'average')

# Get cluster labels
max_d = 1.0  # Adjust this threshold as needed
clusters = fcluster(Z, max_d, criterion='distance')

# Print cluster labels
print("Cluster labels:")
for i, label in enumerate(clusters):
    print(f"Document {i+1}: Cluster {label}")

# Plot dendrogram
plt.figure(figsize=(10, 5))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Index')
plt.ylabel('Distance')
dendrogram(Z, labels=documents, leaf_rotation=90)
plt.show()
# Out:
# Cluster labels:
# Document 1: Cluster 1
# Document 2: Cluster 1
# Document 3: Cluster 2
# Document 4: Cluster 1

# %%
# Perform hierarchical clustering
Z = linkage(tfidf_matrix.toarray(), 'centroid')

# Get cluster labels
max_d = 1.0  # Adjust this threshold as needed
clusters = fcluster(Z, max_d, criterion='distance')

# Print cluster labels
print("Cluster labels:")
for i, label in enumerate(clusters):
    print(f"Document {i+1}: Cluster {label}")

# Plot dendrogram
plt.figure(figsize=(10, 5))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Index')
plt.ylabel('Distance')
dendrogram(Z, labels=documents, leaf_rotation=90)
plt.show()
# Out:
# Cluster labels:
# Document 1: Cluster 1
# Document 2: Cluster 1
# Document 3: Cluster 2
# Document 4: Cluster 1
